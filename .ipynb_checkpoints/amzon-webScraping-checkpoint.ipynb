# %%
from autoscraper import AutoScraper

# %%
amazon_url = "https://www.amazon.in/s?k=wireless+earphone&ref=nb_sb_noss_2"

wanted_list = ["₹1,499","boAt Rockerz 255 Pro+ Bluetooth Wireless in Ear Earphones with Mic (Teal Green)", "402,308"]
#
scraper =AutoScraper()
result = scraper.build(amazon_url, wanted_list)
print(result)
# Out:
# ['₹1,499', '₹3,990', '₹2,990', '₹2,799', '₹7,999', '₹1,099', '₹2,999', '₹999', '₹4,999', '₹599', '₹1,800', '₹799', '₹2,490', '₹1,999', '₹2,190', '₹2,499', '₹699', '₹1,299', '₹798', '₹2,599', '₹1,199', '₹4,490', '₹1,749', '₹1,481', '₹1,446', '₹279', '₹1,599', 'boAt Rockerz 255 Pro+ Bluetooth Wireless in Ear Earphones with Mic (Teal Green)', 'realme Buds Wireless 2 Neo (Black) Earphones with Type-C Fast Charge, Bass Boost+ & Magnetic Instant Connection', 'TEQNEQ Sport Wireless Bluetooth Earphone Neckband, Built-in HD Mic Crystal Clear Voice On Call, Home/Office/Gym Earphone High Bass Noise Cancellation Headphone for All Android Smartphone', 'Wireless Bluetooth Headphones,WAZSAMG Bluetooth Neckband Sport Earphone with Mic, Bass+HD Stereo 8 Hrs Playtime in Ear Wireless Earbuds,IPX7 Waterproof Running Headphones(red)', 'TEQNEQ Sport Wireless Bluetooth Earphone Neckband, Built-in HD Mic Crystal Clear Voice On Call, Home/Office/Gym Earphone H...', 'Wireless Bluetooth Headphones,WAZSAMG Bluetooth Neckband Sport Earphone with Mic, Bass+HD Stereo 8 Hrs Playtime in Ear Wir...', 'boAt Rockerz 330 Pro Wireless Neckband with 60HRS Playtime, ASAPTM Charge, ENxTM Tech, Bluetooth v5.2, Dual Pairing, IPX5, Magnetic Earbuds, 10mm Drivers(Raging Red)', 'Noise Air Buds Pro Truly Wireless Earbuds with Active Noise Cancellation, Quad Mic, Transparency Mode, & Hyper Sync Technology (Celeste Blue)', 'pTron Bassbuds Sports True Wireless Bluetooth 5.1 Headphones with Deep Bass, 32Hrs Total Playtime, Ergonomic Hook Design & IPX4 Water/Sweat Resistant Earphones with Built-in HD Mic (Black & Blue)', 'Noise Buds VS201 V2 Truly Wireless Earbuds with Dual Equalizer | Total 14-Hour Playtime | Full Touch Control | IPX5 Water Resistance and Bluetooth v5.1 (Olive Green)', 'Boult Audio ProBass Qcharge in-Ear Earphones with Fast Charging, 24H Battery Life, in-Built Mic, IPX5 Water Resistant Neckband (Black)']

# %%
scraper.get_result_similar(amazon_url, grouped=True)
# Out:
# {'rule_v5ph': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,990',
#   '₹2,799',
#   '₹7,999',
#   '₹1,099',
#   '₹2,999',
#   '₹1,499',
#   '₹2,999',
#   '₹999',
#   '₹4,999'],
#  'rule_hwlc': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,990',
#   '₹2,799',
#   '₹7,999',
#   '₹1,099',
#   '₹2,999',
#   '₹1,499',
#   '₹2,999',
#   '₹999',
#   '₹4,999'],
#  'rule_b52d': ['₹1,999',
#   '₹2,190',
#   '₹1,999',
#   '₹2,190',
#   '₹1,499',
#   '₹2,499',
#   '₹1,099',
#   '₹2,999',
#   '₹1,299',
#   '₹2,990',
#   '₹599',
#   '₹1,800',
#   '₹1,499',
#   '₹3,990',
#   '₹799',
#   '₹2,490',
#   '₹999',
#   '₹2,799',
#   '₹699',
#   '₹2,499',
#   '₹279',
#   '₹999',
#   '₹999',
#   '₹2,990',
#   '₹699',
#   '₹2,299',
#   '₹799',
#   '₹1,999',
#   '₹799',
#   '₹2,490',
#   '₹249',
#   '₹999'],
#  'rule_jm3c': ['₹1,999',
#   '₹2,190',
#   '₹1,999',
#   '₹2,190',
#   '₹1,499',
#   '₹2,499',
#   '₹1,099',
#   '₹2,999',
#   '₹1,299',
#   '₹2,990',
#   '₹599',
#   '₹1,800',
#   '₹1,499',
#   '₹3,990',
#   '₹799',
#   '₹2,490',
#   '₹999',
#   '₹2,799',
#   '₹699',
#   '₹2,499',
#   '₹279',
#   '₹999',
#   '₹999',
#   '₹2,990',
#   '₹699',
#   '₹2,299',
#   '₹799',
#   '₹1,999',
#   '₹799',
#   '₹2,490',
#   '₹249',
#   '₹999'],
#  'rule_zvsh': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,499',
#   '₹279',
#   '₹999',
#   '₹799',
#   '₹1,599'],
#  'rule_fp70': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,499',
#   '₹279',
#   '₹999',
#   '₹799',
#   '₹1,599'],
#  'rule_p3mu': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,499',
#   '₹279',
#   '₹999',
#   '₹799',
#   '₹1,599'],
#  'rule_mjq6': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,499',
#   '₹279',
#   '₹999',
#   '₹799',
#   '₹1,599'],
#  'rule_a1z1': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,990',
#   '₹2,799',
#   '₹7,999',
#   '₹1,099',
#   '₹2,999',
#   '₹1,499',
#   '₹2,999',
#   '₹999',
#   '₹4,999'],
#  'rule_bflm': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,990',
#   '₹2,799',
#   '₹7,999',
#   '₹1,099',
#   '₹2,999',
#   '₹1,499',
#   '₹2,999',
#   '₹999',
#   '₹4,999'],
#  'rule_5ngo': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,990',
#   '₹2,799',
#   '₹7,999',
#   '₹1,099',
#   '₹2,999',
#   '₹1,499',
#   '₹2,999',
#   '₹999',
#   '₹4,999'],
#  'rule_qmbh': ['₹1,499',
#   '₹3,990',
#   '₹1,499',
#   '₹2,990',
#   '₹2,799',
#   '₹7,999',
#   '₹1,099',
#   '₹2,999',
#   '₹1,499',
#   '₹2,999',
#   '₹999',
#   '₹4,999'],
#  'rule_al1q': ['boAt Rockerz 255 Pro+ Bluetooth Wireless in Ear Earphones with Mic (Teal Green)',
#   'realme Buds Wireless 2 Neo (Black) Earphones with Type-C Fast Charge, Bass Boost+ & Magnetic Instant Connection',
#   'TEQNEQ Sport Wireless Bluetooth Earphone Neckband, Built-in HD Mic Crystal Clear Voice On Call, Home/Office/Gym Earphone High Bass Noise Cancellation Headphone for All Android Smartphone',
#   'Wireless Bluetooth Headphones,WAZSAMG Bluetooth Neckband Sport Earphone with Mic, Bass+HD Stereo 8 Hrs Playtime in Ear Wireless Earbuds,IPX7 Waterproof Running Headphones(red)'],
#  'rule_9ham': ['boAt Rockerz 255 Pro+ Bluetooth Wireless in Ear Earphones with Mic (Teal Green)',
#   'realme Buds Wireless 2 Neo (Black) Earphones with Type-C Fast Charge, Bass Boost+ & Magnetic Instant Connection',
#   'TEQNEQ Sport Wireless Bluetooth Earphone Neckband, Built-in HD Mic Crystal Clear Voice On Call, Home/Office/Gym Earphone H...',
#   'Wireless Bluetooth Headphones,WAZSAMG Bluetooth Neckband Sport Earphone with Mic, Bass+HD Stereo 8 Hrs Playtime in Ear Wir...'],
#  'rule_dsod': ['boAt Rockerz 255 Pro+ Bluetooth Wireless in Ear Earphones with Mic (Teal Green)',
#   'boAt Rockerz 330 Pro Wireless Neckband with 60HRS Playtime, ASAPTM Charge, ENxTM Tech, Bluetooth v5.2, Dual Pairing, IPX5, Magnetic Earbuds, 10mm Drivers(Raging Red)',
#   'Noise Air Buds Pro Truly Wireless Earbuds with Active Noise Cancellation, Quad Mic, Transparency Mode, & Hyper Sync Technology (Celeste Blue)',
#   'pTron Bassbuds Sports True Wireless Bluetooth 5.1 Headphones with Deep Bass, 32Hrs Total Playtime, Ergonomic Hook Design & IPX4 Water/Sweat Resistant Earphones with Built-in HD Mic (Black & Blue)',
#   'Noise Buds VS201 V2 Truly Wireless Earbuds with Dual Equalizer | Total 14-Hour Playtime | Full Touch Control | IPX5 Water Resistance and Bluetooth v5.1 (Olive Green)',
#   'Boult Audio ProBass Qcharge in-Ear Earphones with Fast Charging, 24H Battery Life, in-Built Mic, IPX5 Water Resistant Neckband (Black)']}
